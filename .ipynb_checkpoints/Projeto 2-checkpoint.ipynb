# %% [markdown]
# ## PROJETO 2
# <img src="diabetes.jpg"height="400">

# %%
# Importando as bibliotecas necessárias para esta atividade
import pandas as pd

# %%
# Importando biblioteca para Sistema Operacional
import os

# %%
print(f'Esperamos trabalhar no diretório: \n{os.getcwd()}\n')
# Out:
# Esperamos trabalhar no diretório:
# C:\Users\gusta\OneDrive\Área de Trabalho\projeto 2\22-2b-cd-p2-p2_gustavo_fabio_vini_yuri

# %%
filename = 'diabetes.xlsx'

if filename in os.listdir():
    print(f'Parece que o arquivo {filename} está na mesma pasta do notebook, yay!')
    
else:
    print(f'Não encontrei o arquivo {filename}')
# Out:
# Parece que o arquivo diabetes.xlsx está na mesma pasta do notebook, yay!

# %%
dados = pd.read_excel('diabetes.xlsx')
dados
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ANALISE EXPLORATORIA
